# %%
import streamlit as st
import pandas as pd
import joblib
import os
import json
import random
import requests
import altair as alt
from ytmusicapi import YTMusic

# %%
# --- PAGE CONFIGURATION ---
st.set_page_config(
    page_title="SoundBox - Mood Music",
    page_icon="🎵",
    layout="wide",
    initial_sidebar_state="expanded"
)
# Out:
# 2026-01-11 15:38:42.293 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# --- CONFIG & DATA LOADING ---
@st.cache_resource
def load_data_pipeline():
    if os.path.exists('model.pkl'):
        return joblib.load('model.pkl')
    return None

def load_liked_songs():
    if os.path.exists('liked_songs.json'):
        with open('liked_songs.json', 'r') as f:
            return json.load(f)
    return []

def save_liked_songs(liked_list):
    with open('liked_songs.json', 'w') as f:
        json.dump(liked_list, f)

# Initialize Session State
if 'liked_songs' not in st.session_state:
    st.session_state.liked_songs = load_liked_songs()
if 'current_view' not in st.session_state:
    st.session_state.current_view = 'Dashboard'
if 'selected_emoji' not in st.session_state:
    st.session_state.selected_emoji = None
if 'recommendations' not in st.session_state:
    st.session_state.recommendations = []
if 'current_video_id' not in st.session_state:
    st.session_state.current_video_id = None
if 'current_playing_song_name' not in st.session_state:
    st.session_state.current_playing_song_name = None
if 'last_selected_lang' not in st.session_state:
    st.session_state.last_selected_lang = 'English'

# Load Assets
artifacts = load_data_pipeline()
if artifacts:
    df_songs = artifacts['data']
    # Ensure language column exists for compatibility
    if 'language' not in df_songs.columns:
        df_songs['language'] = 'English'
else:
    st.error("Dataset not found. Please run `train_model.py` first to fetch data from iTunes.")
    st.stop()
# Out:
# 2026-01-11 15:38:42.305 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:42.305 WARNING streamlit.runtime.state.session_state_proxy: Session state does not function when running a script without `streamlit run`
# 2026-01-11 15:38:42.319 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:42.321 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:42.322 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:42.323 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:42.323 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:42.324 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:42.325 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:42.326 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:42.327 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:42.328 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:42.329 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:42.329 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:42.330 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:42.331 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:42.332 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:42.332 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:42.333 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:42.334 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:42.334 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:42.335 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:42.336 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.015
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-01-11 15:38:43.017 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.017 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.018 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.034 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.034 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.035 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# --- HELPER FUNCTIONS ---
def search_itunes(query, limit=10):
    url = "https://itunes.apple.com/search"
    params = {'term': query, 'media': 'music', 'entity': 'song', 'limit': limit}
    try:
        response = requests.get(url, params=params, timeout=5)
        if response.status_code == 200:
            results = []
            for item in response.json().get('results', []):
                results.append({
                    'id': str(item.get('trackId')),
                    'name': item.get('trackName'),
                    'artist': item.get('artistName'),
                    'album': item.get('collectionName'),
                    'image_url': item.get('artworkUrl100').replace('100x100', '600x600'),
                    'preview_url': item.get('previewUrl'),
                })
            return results
    except:
        return []
    return []

@st.cache_resource
def get_ytmusic():
    return YTMusic()

def get_youtube_video_id(query):
    try:
        yt = get_ytmusic()
        results = yt.search(query, filter='songs', limit=1)
        if results:
            return results[0]['videoId']
        # Fallback to general search if song filter fails
        results = yt.search(query, limit=1)
        if results:
            return results[0]['videoId']
    except Exception as e:
        print(f"YouTube Search Error: {e}")
    return None

# %%
# --- CUSTOM CSS (NETFLIX STYLE) ---
st.markdown("""
<style>
    @import url('https://fonts.googleapis.com/css2?family=Bebas+Neue&family=Poppins:wght@400;700&display=swap');

    /* MAIN BACKGROUND */
    .stApp {
        background-color: #141414;
        color: #ffffff;
        font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif;
    }
    
    /* HIDE SIDEBAR */
    [data-testid="stSidebar"] {
        display: none;
    }
    
    /* NAVBAR */
    .nav-container {
        display: flex;
        justify_content: space-between;
        align_items: center;
        padding: 10px 20px;
        background: linear-gradient(to bottom, rgba(0,0,0,0.9) 0%, rgba(0,0,0,0) 100%);
        position: sticky;
        top: 0;
        z-index: 999;
    }
    
    /* BRANDING */
    .netflix-brand {
        font-family: 'Bebas Neue', sans-serif;
        color: #E50914;
        font-size: 3.5rem; /* Increased from 2.5rem */
        font-weight: bold;
        text-shadow: 2px 2px 4px rgba(0,0,0,0.5);
        letter-spacing: 2px;
    }
    
    /* NAV BUTTONS */
    .stButton button {
        background-color: transparent !important;
        color: #e5e5e5 !important;
        border: none !important;
        font-weight: bold;
        transition: color 0.3s;
    }
    .stButton button:hover {
        color: #b3b3b3 !important;
    }
    .stButton button:focus {
        color: #ffffff !important;
    }
    
    /* PRIMARY (ACTIVE) BUTTON HIGHLIGHT */
    div[data-testid="stButton"] button[kind="primary"] {
        background-color: #E50914 !important;
        color: #ffffff !important;
        border: none !important;
        box-shadow: 0 0 15px rgba(229, 9, 20, 0.4);
    }
    
    /* HERO BANNER */
    .hero-container {
        position: relative;
        width: 100%;
        height: 400px;
        background: linear-gradient(to top, #141414 10%, transparent 100%),
                    url('https://images.unsplash.com/photo-1511671782779-c97d3d27a1d4?q=80&w=2070&auto=format&fit=crop'); 
        background-size: cover;
        background-position: center;
        display: flex;
        flex-direction: column;
        justify-content: flex-end;
        padding: 40px;
        margin-bottom: 20px;
        border-radius: 8px;
    }
    
    .hero-title {
        font-size: 5rem; /* Increased from 4rem */
        font-weight: 800;
        color: white;
        margin-bottom: 10px;
        text-shadow: 2px 2px 10px rgba(0,0,0,0.8);
    }
    
    .hero-subtitle {
        font-size: 1.2rem;
        color: #e5e5e5;
        max-width: 600px;
        margin-bottom: 20px;
        text-shadow: 1px 1px 5px rgba(0,0,0,0.8);
    }
    
    /* MOOD ROW */
    .mood-item {
        background-color: #181818;
        border: 1px solid #333;
        border-radius: 4px;
        padding: 10px;
        text-align: center;
        cursor: pointer;
        transition: transform 0.2s, border-color 0.2s;
    }
    .mood-item:hover {
        transform: scale(1.05);
        border-color: #E50914;
    }
    
    /* SONG CARD (POSTER STYLE) */
    .song-card {
        background-color: #2F2F2F;
        border-radius: 4px;
        overflow: hidden;
        transition: transform 0.3s;
        margin-bottom: 20px;
        height: 100%;
        position: relative;
    }
    .song-card:hover {
        transform: scale(1.05);
        z-index: 10;
        box-shadow: 0 10px 20px rgba(0,0,0,0.5);
    }
    .song-card img {
        width: 100%;
        aspect-ratio: 1/1;
        object-fit: cover;
    }
    .card-content {
        padding: 10px;
    }
    .song-title {
        font-size: 0.9rem;
        font-weight: bold;
        white-space: nowrap;
        overflow: hidden;
        text-overflow: ellipsis;
        color: white;
    }
    .song-artist {
        font-size: 0.75rem;
        color: #b3b3b3;
    }
</style>
""", unsafe_allow_html=True)
# Out:
# 2026-01-11 15:38:43.057 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.058 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.059 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
# --- NAVBAR & NAVIGATION ---
# Top Bar: Brand | Navigation | Language
c_brand, c_nav1, c_nav2, c_nav3, c_lang = st.columns([2, 1, 1, 1, 1.5])

with c_brand:
    st.markdown('<div class="netflix-brand">EMOTIFY</div>', unsafe_allow_html=True)

with c_nav1:
    if st.button("Home"):
        st.session_state.current_view = 'Dashboard'
with c_nav2:
    if st.button("My List"): # Netflix terminology for Favorites
        st.session_state.current_view = 'Favorites'
with c_nav3:
    if st.button("Search"):
        st.session_state.current_view = 'Search'

with c_lang:
    # Minimalist language selector
    available_langs = ['English', 'Hindi', 'Spanish', 'Korean', 'Telugu']
    if 'language' in df_songs.columns:
        data_langs = sorted(df_songs['language'].dropna().unique().tolist())
        available_langs = sorted(list(set(available_langs + data_langs)))
        
    default_index = 0
    if 'English' in available_langs:
        default_index = available_langs.index('English')
    
    # Using label_visibility="collapsed" for cleaner look
    selected_lang = st.selectbox("Lang", available_langs, index=default_index, label_visibility="collapsed")
    
    # DETECT LANGUAGE CHANGE
    if selected_lang != st.session_state.last_selected_lang:
        st.session_state.last_selected_lang = selected_lang
        # If a mood was selected, automatically refresh recommendations for the new language
        if st.session_state.selected_emoji:
            mask = (df_songs['predicted_emoji'] == st.session_state.selected_emoji)
            if 'language' in df_songs.columns:
                mask = mask & (df_songs['language'] == selected_lang)
            recs = df_songs[mask]
            if not recs.empty:
                st.session_state.recommendations = recs.sample(min(20, len(recs))).to_dict('records')
            else:
                st.session_state.recommendations = []
        else:
            st.session_state.recommendations = [] # Clear if no mood selected
        st.rerun()
# Out:
# 2026-01-11 15:38:43.077 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.079 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.079 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.080 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.081 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.081 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.082 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.083 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.083 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.084 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.085 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.086 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.086 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.087 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.088 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.088 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.089 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.090 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.090 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.091 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.092 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.092 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.093 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.094 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.094 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.094 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.095 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.101 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.102 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.103 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.103 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.104 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.105 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.106 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.107 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# --- MAIN CONTENT ---
view = st.session_state.current_view

# --- GLOBAL VIDEO PLAYER ---
if st.session_state.current_video_id:
    # Moved to "Middle" (Main Column) as requested
    st.markdown("---")
    c_video, c_info = st.columns([2, 1])
    # Custom Autoplay Embed
    embed_url = f"https://www.youtube.com/embed/{st.session_state.current_video_id}?autoplay=1&rel=0"
    st.components.v1.html(f"""
        <iframe width="100%" height="450" src="{embed_url}" 
                frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" 
                allowfullscreen style="border-radius:12px; box-shadow: 0 10px 30px rgba(0,0,0,0.5);">
        </iframe>
    """, height=480)
    
    if st.button("Stop Player", key="close_player_main"):
        st.session_state.current_video_id = None
        st.session_state.current_playing_song_name = None
        st.rerun()
    st.markdown("---")
# Out:
# 2026-01-11 15:38:43.116 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.117 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
if view == 'Dashboard':
    # --- HERO SECTION ---
    st.markdown("""
    <div class="hero-container">
        <div class="hero-title">FEEL THE BEAT</div>
        <div class="hero-subtitle">Discover the perfect soundtrack for your current mood. Select an option below to start listening.</div>
    </div>
    """, unsafe_allow_html=True)
    
    # --- MOOD ROW (Horizontal) ---
    st.markdown("### 🎭 Browse by Mood")
    emojis = {
        'Happy': '😊', 'Sad': '😢', 'Relaxed': '😌', 
        'Energy': '🔥', 'Focus': '💪', 'Sleep': '😴',
        'Love': '🥰', 'Angry': '😠', 'Party': '🎉'
    }
    
    # Create a horizonatal scrollable-like feel with columns
    cols = st.columns(len(emojis))
    for i, (label, emoji) in enumerate(emojis.items()):
        with cols[i]:
            # Highlight logic: use primary type for selected emoji
            is_selected = (st.session_state.selected_emoji == emoji)
            if st.button(f"{emoji}\n{label}", 
                         key=f"mood_{i}", 
                         use_container_width=True,
                         type="primary" if is_selected else "secondary"):
                st.session_state.selected_emoji = emoji
                
                # Filter Logic
                mask = (df_songs['predicted_emoji'] == emoji)
                if 'language' in df_songs.columns:
                    mask = mask & (df_songs['language'] == selected_lang)
                recs = df_songs[mask]
                
                if not recs.empty:
                    st.session_state.recommendations = recs.sample(min(20, len(recs))).to_dict('records') # Increased sample size for grid
                else:
                    st.warning(f"No {selected_lang} songs found for this mood.")
                    st.session_state.recommendations = []

    # --- SONG POSTER GRID ---
    st.markdown(f"### 🍿 Top Picks for You ({selected_lang})")
    
    active_list = st.session_state.recommendations
    if not active_list:
         # Default/Trending
         if 'language' in df_songs.columns:
             default_recs = df_songs[df_songs['language'] == selected_lang]
             if not default_recs.empty:
                 active_list = default_recs.sample(min(12, len(default_recs))).to_dict('records')
         
         if not active_list:
             active_list = df_songs.sample(min(12, len(df_songs))).to_dict('records')
         
         st.caption("Trending Now")
    else:
        st.caption(f"Because you're feeling {st.session_state.selected_emoji}")

    # Display Grid (4 columns)
    cols = st.columns(4)
    for i, song in enumerate(active_list):
        with cols[i % 4]:
            # CLICKABLE POSTER WRAPPER
            # We use a button that looks like a card
            st.markdown(f"""
            <div class="song-card">
                <img src="{song.get('image_url') or 'https://placehold.co/300x300'}" />
                <div class="card-content">
                    <div class="song-title">{song['name']}</div>
                    <div class="song-artist">{song['artist']}</div>
                </div>
            </div>
            """, unsafe_allow_html=True)
            
            # Action Buttons below the card
            c_play, c_like = st.columns([3, 1])
            with c_play:
                # MAKING THIS THE MAIN ACTION - Clicking Play also covers the 'poster' intent
                if st.button("▶ Play", key=f"grid_play_{song['id']}", use_container_width=True, type="primary"):
                     st.toast(f"Starting {song['name']}...")
                     vid_id = get_youtube_video_id(f"{song['name']} {song['artist']} audio")
                     if vid_id:
                         st.session_state.current_video_id = vid_id
                         st.session_state.current_playing_song_name = song['name']
                         st.rerun()
            with c_like:
                is_liked = any(s['id'] == song['id'] for s in st.session_state.liked_songs)
                if st.button("❤️" if is_liked else "➕", key=f"grid_like_{song['id']}", use_container_width=True):
                    if is_liked:
                        st.session_state.liked_songs = [s for s in st.session_state.liked_songs if s['id'] != song['id']]
                    else:
                        st.session_state.liked_songs.append(song)
                    save_liked_songs(st.session_state.liked_songs)
                    st.rerun()
# Out:
# 2026-01-11 15:38:43.133 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.134 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.135 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.135 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.136 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.136 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.137 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.138 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.139 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.139 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.139 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.140 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.141 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.141 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.142 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.142 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.143 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.143 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.144 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.144 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.147 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.147 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.148 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.149 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.149 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.150 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.151 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.151 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.152 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.153 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.153 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.154 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.154 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.156 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.156 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.157 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.157 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.157 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.159 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.159 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.159 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.168 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.168 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.168 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.170 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.170 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.171 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.173 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.173 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.173 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.176 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.176 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.177 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.178 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.178 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.178 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.193 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.194 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.196 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.197 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.197 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.198 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.198 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.199 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.200 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.200 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.202 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.202 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.203 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.203 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.204 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.204 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.206 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.206 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.207 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.207 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.207 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.209 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.212 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.215 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.217 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.218 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.219 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.220 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.220 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.222 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.222 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.223 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.223 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.224 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.225 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.226 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.227 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.227 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.228 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.228 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.229 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.229 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.230 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.231 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.231 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.232 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.232 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.232 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.234 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.234 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.235 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.235 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.236 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.236 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.237 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.237 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.238 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.238 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.239 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.239 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.240 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.240 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.241 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.241 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.242 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.242 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.243 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.243 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.244 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.244 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.245 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.245 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.246 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.246 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.247 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.248 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.248 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.249 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.249 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.250 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.250 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.251 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.252 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.253 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.254 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.254 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.255 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.256 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.256 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.257 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.258 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.258 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.259 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.260 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.260 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.261 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.263 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.264 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.264 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.265 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.265 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.266 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.266 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.267 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.270 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.270 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.271 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.272 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.272 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.273 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.273 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.274 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.276 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.277 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.277 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.278 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.278 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.281 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.282 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.283 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.284 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.284 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.284 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.285 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.285 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.286 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.286 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.286 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.287 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.287 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.289 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.289 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.291 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.292 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.293 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.294 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.295 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.296 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.297 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.297 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.298 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.298 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.299 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.299 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.300 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.300 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.301 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.301 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.302 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.302 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.302 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.303 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.304 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.304 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.304 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.305 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.305 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.306 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.306 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.307 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.307 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.308 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.308 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.309 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.310 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.310 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.310 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.311 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.311 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.312 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.314 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.315 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.315 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.316 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.317 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.317 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.318 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.318 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.319 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.319 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.319 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.320 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.320 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.321 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.322 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.323 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.323 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.324 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.324 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.325 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.325 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.326 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.326 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.327 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.327 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.327 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.328 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.328 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.329 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.329 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.329 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.330 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.330 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.331 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.332 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.333 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.334 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.334 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.334 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.335 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.335 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.336 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.336 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.337 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.338 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.338 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.339 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.340 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.340 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.341 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.342 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-11 15:38:43.342 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
if view == 'Search':
    st.markdown(f"### 🔍 Find Your Track ({selected_lang})")
    search_query = st.text_input("", placeholder=f"Search {selected_lang} songs...")
    
    if search_query:
        st.markdown(f"Results for '{search_query}'")
        
        # Append Language to Query to respect filter
        full_query = f"{search_query} {selected_lang}"
        results = search_itunes(full_query) 
        
        cols = st.columns(4)
        for i, song in enumerate(results):
            with cols[i % 4]:
                st.markdown(f"""
                <div class="song-card">
                    <img src="{song.get('image_url') or 'https://placehold.co/300x300'}" />
                    <div class="card-content">
                        <div class="song-title">{song['name']}</div>
                        <div class="song-artist">{song['artist']}</div>
                    </div>
                </div>
                """, unsafe_allow_html=True)
                
                # Action Buttons
                c_play, c_like = st.columns([3, 1])
                with c_play:
                    if st.button("▶ Play Now", key=f"s_play_{song['id']}", use_container_width=True, type="primary"):
                         st.toast(f"Loading {song['name']}...")
                         vid_id = get_youtube_video_id(f"{song['name']} {song['artist']} audio")
                         if vid_id:
                             st.session_state.current_video_id = vid_id
                             st.session_state.current_playing_song_name = song['name']
                             st.rerun()
                with c_like:
                    is_liked = any(s['id'] == song['id'] for s in st.session_state.liked_songs)
                    if st.button("❤️" if is_liked else "➕", key=f"s_like_{song['id']}", use_container_width=True):
                         if is_liked:
                            st.session_state.liked_songs = [s for s in st.session_state.liked_songs if s['id'] != song['id']]
                         else:
                            st.session_state.liked_songs.append(song)
                         save_liked_songs(st.session_state.liked_songs)
                         st.rerun()

# %%
if view == 'Favorites':
    st.markdown("### ❤️ My List")
    if st.session_state.liked_songs:
        cols = st.columns(4)
        for i, song in enumerate(st.session_state.liked_songs):
            with cols[i % 4]:
                st.markdown(f"""
                <div class="song-card">
                    <img src="{song.get('image_url') or 'https://placehold.co/300x300'}" />
                    <div class="card-content">
                        <div class="song-title">{song['name']}</div>
                        <div class="song-artist">{song['artist']}</div>
                    </div>
                </div>
                """, unsafe_allow_html=True)
                
                c_play, c_remove = st.columns([3, 1])
                with c_play:
                    if st.button("▶ Play Now", key=f"f_play_{song['id']}", use_container_width=True, type="primary"):
                         st.toast(f"Starting...")
                         vid_id = get_youtube_video_id(f"{song['name']} {song['artist']} audio")
                         if vid_id:
                             st.session_state.current_video_id = vid_id
                             st.session_state.current_playing_song_name = song['name']
                             st.rerun()
                with c_remove:
                    if st.button("❌", key=f"f_remove_{song['id']}", use_container_width=True):
                        st.session_state.liked_songs.remove(song)
                        save_liked_songs(st.session_state.liked_songs)
                        st.rerun()
    else:
        st.info("No liked songs yet.")
